# %%
import pandas as pd
import numpy as np

# %%
df_2020 = pd.read_csv('players_2020.csv')

# %%
df_2020.head()
# Out:
#    fide_id                name federation gender title   yob  year  month  \
# 0   100013  Campora, Daniel H.        ARG      M    GM  1957  2020      1
# 1   100013  Campora, Daniel H.        ARG      M    GM  1957  2020      2
# 2   100013  Campora, Daniel H.        ARG      M    GM  1957  2020      3
# 3   100013  Campora, Daniel H.        ARG      M    GM  1957  2020      4
# 4   100013  Campora, Daniel H.        ARG      M    GM  1957  2020      5
#
#    rating_standard
# 0           2420.0
# 1           2429.0
# 2           2420.0
# 3           2420.0
# 4           2420.0

# %%
grouped_df = df_2020.groupby("federation")
grouped_df.head()
# Out:
#           fide_id                name federation gender title   yob  year  \
# 0          100013  Campora, Daniel H.        ARG      M    GM  1957  2020
# 1          100013  Campora, Daniel H.        ARG      M    GM  1957  2020
# 2          100013  Campora, Daniel H.        ARG      M    GM  1957  2020
# 3          100013  Campora, Daniel H.        ARG      M    GM  1957  2020
# 4          100013  Campora, Daniel H.        ARG      M    GM  1957  2020
# ...           ...                 ...        ...    ...   ...   ...   ...
# 4188138  31900062      Cardoso, Saula        TLS      F   NaN  1984  2020
# 4188139  31900062      Cardoso, Saula        TLS      F   NaN  1984  2020
# 4188140  31900062      Cardoso, Saula        TLS      F   NaN  1984  2020
# 4188141  31900062      Cardoso, Saula        TLS      F   NaN  1984  2020
# 4188142  31900062      Cardoso, Saula        TLS      F   NaN  1984  2020
#
#          month  rating_standard
# 0            1           2420.0
# ...

# %%
sorted_df = grouped_df.sort_values(['federation','rating_standard'], ascending=(True, False))
sorted_df.head(50)
# Out:
#           fide_id                  name federation gender title   yob  year  \
# 2556336  11700840  Haidary, Hameedullah        AFG      M   NaN  1975  2020
# 2556335  11700840  Haidary, Hameedullah        AFG      M   NaN  1975  2020
# 2556334  11700840  Haidary, Hameedullah        AFG      M   NaN  1975  2020
# 2556333  11700840  Haidary, Hameedullah        AFG      M   NaN  1975  2020
# 2556332  11700840  Haidary, Hameedullah        AFG      M   NaN  1975  2020
# 2556331  11700840  Haidary, Hameedullah        AFG      M   NaN  1975  2020
# 2556325  11700840  Haidary, Hameedullah        AFG      M   NaN  1975  2020
# 2556326  11700840  Haidary, Hameedullah        AFG      M   NaN  1975  2020
# 2556330  11700840  Haidary, Hameedullah        AFG      M   NaN  1975  2020
# 2556329  11700840  Haidary, Hameedullah        AFG      M   NaN  1975  2020
# 2556328  11700840  Haidary, Hameedullah        AFG      M   NaN  1975  2020
# ...

# %%
drop_df = sorted_df.drop_duplicates(subset='federation', keep='first')
drop_df.head(50)
# Out:
#           fide_id                               name federation gender title  \
# 2556336  11700840               Haidary, Hameedullah        AFG      M   NaN
# 604288    1020870                         Vos, Tjark        AHO      M   NaN
# 1972781   4700236                    Dervishi, Erald        ALB      M    GM
# 355120     696358                   Bellahcene,Bilel        ALG      M    GM
# 192840     400106                   Norwood, David R        AND      M    GM
# 2429537  10100792                     Miguel, Sergio        ANG      M    FM
# 3574947  23800089                  Fleming, Hannibal        ANT      M   NaN
# 10360      110973                       Pichot, Alan        ARG      M    GM
# 2756134  13300474                     Aronian, Levon        ARM      M    GM
# 3156230  15900045                       Lopez, Jasel        ARU      M    IM
# 1455925   3208923                     Smirnov, Anton        AUS      M    GM
# ...

# %%
drop_df.to_csv(r'players_by_country.csv', index = False)
